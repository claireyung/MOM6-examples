# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
import cmocean as cm

from xgcm import Grid

# %%
IC = xr.open_dataset('Initial_state.nc')

# %%
ideal_salt = xr.zeros_like(IC.Salt) + (IC.eta.isel(Interface = 0)-IC.h.cumsum('Layer')+IC.h/2)*(36-34)/(-4000) + 33.8
(IC.Salt-ideal_salt).isel(lath = 0).plot(yincrease = False)
plt.title('REMAP_BOUNDARY_EXTRAP = False')
plt.show()
