# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
import cmocean as cm
from xgcm import Grid

# %%
ISOMIP_FILE = xr.open_dataset('sigmashelfz-ISOMIPtopo-shelf/INPUT/Ocean1_3D.nc')
ISOMIP_FILE.thick.plot()

# %%
ISOMIP_FILE.thick.diff('nx').plot()

# %%
ISOMIP_FILE.thick.diff('ny').plot()

# %%
ISOMIP_FILE.thick.isel(ny = 8).plot(marker = 'o')

# %%
ISOMIP_FILE.thick.isel(ny = 8).plot(marker = 'o')
plt.xlim(60,80)
plt.ylim(400,700)
# Out:
# (400.0, 700.0)

# %%
ASAYDAVISNETCDF = xr.open_dataset('Ocean1_input_geom_v1.01.nc')

# %%
ASAYDAVISNETCDF
# Out:
# <xarray.Dataset>
# Dimensions:            (x: 480, y: 80)
# Coordinates:
#   * x                  (x) float64 3.205e+05 3.215e+05 ... 7.985e+05 7.995e+05
#   * y                  (y) float64 500.0 1.5e+03 2.5e+03 ... 7.85e+04 7.95e+04
# Data variables:
#     upperSurface       (y, x) float64 ...
#     lowerSurface       (y, x) float64 ...
#     bedrockTopography  (y, x) float64 ...
#     floatingMask       (y, x) float64 ...
#     groundedMask       (y, x) float64 ...
#     openOceanMask      (y, x) float64 ...

# %%
ASAYDAVISNETCDF.lowerSurface.plot()

# %%
(ASAYDAVISNETCDF.upperSurface-ASAYDAVISNETCDF.lowerSurface).plot(cmap = 'rainbow')

# %%
ASAYDAVISNETCDF.lowerSurface.isel(y = 40).plot()

# %%
ASAYDAVISNETCDF.bedrockTopography.isel(y = 40).plot()

# %%
ISOMIP_FILE.thick.isel(ny = 20).plot()

# %% [markdown]
# # Very sharp compared to the one I was given.
