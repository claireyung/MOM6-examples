# %% [markdown]
# # MOM6 Momentum Budget
#
# Link: https://mom6-analysiscookbook.readthedocs.io/en/latest/notebooks/Closing_momentum_budget.html#Budget-for-depth-av
#
# `dudt = CAu + PFu + u_BT_accel + diffu + du_dt_visc +` residual due to remapping
#
# Start with x direction as velocities bigger

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
import cmocean as cm
from xgcm import Grid

# %%
def open_IC():
    IC = xr.open_dataset('Initial_state.nc')
    return IC
def open_prog():
    prog = xr.open_dataset('prog.nc')
    return prog
def open_mom():
    mom = xr.open_dataset('mom.nc')
    return mom

# %%
IC = open_IC()
prog = open_prog()
mom = open_mom()

# %%
mom
# Out:
# <xarray.Dataset>
# Dimensions:     (xq: 241, yh: 40, zl: 20, Time: 120, xh: 240, yq: 41)
# Coordinates:
#   * xq          (xq) float64 320.0 322.0 324.0 326.0 ... 794.0 796.0 798.0 800.0
#   * yh          (yh) float64 1.0 3.0 5.0 7.0 9.0 ... 71.0 73.0 75.0 77.0 79.0
#   * zl          (zl) float64 18.0 54.0 90.0 126.0 ... 594.0 630.0 666.0 702.0
#   * Time        (Time) object 0001-01-01 01:00:00 ... 0001-01-06 00:00:00
#   * xh          (xh) float64 321.0 323.0 325.0 327.0 ... 793.0 795.0 797.0 799.0
#   * yq          (yq) float64 0.0 2.0 4.0 6.0 8.0 ... 72.0 74.0 76.0 78.0 80.0
# Data variables: (12/16)
#     dudt        (Time, zl, yh, xq) float64 ...
#     dvdt        (Time, zl, yq, xh) float64 ...
#     CAu         (Time, zl, yh, xq) float64 ...
#     CAv         (Time, zl, yq, xh) float64 ...
#     PFu         (Time, zl, yh, xq) float64 ...
#     PFv         (Time, zl, yq, xh) float64 ...
#     ...          ...
#     du_dt_visc  (Time, zl, yh, xq) float64 ...
# ...

# %% [markdown]
# Let us first plot the x momentum balance in bottom layer at time t = 1 h

# %%
tt = 0
zz = -1
fig,axes = plt.subplots(nrows = 3, ncols = 4, figsize = (20,12))
prog.salt.isel(Time = tt, zl = zz).plot(ax = axes[0,0])
axes[0,0].set_title('salt')

prog.h.isel(Time = tt, zl = zz).plot(ax = axes[0,1])
axes[0,1].set_title('layer thickness')

mom.CAu.isel(Time = tt, zl = zz).plot(ax = axes[0,2])
axes[0,2].set_title('CAu')

mom.PFu.isel(Time = tt, zl = zz).plot(ax = axes[0,3])
axes[0,3].set_title('PFu')

mom.u_accel_bt.isel(Time = tt).plot(ax = axes[1,0])## no z dependence
axes[1,0].set_title('u_accel_bt')

mom.diffu.isel(Time = tt, zl = zz).plot(ax = axes[1,1]) 
axes[1,1].set_title('diffu')

mom.du_dt_visc.isel(Time = tt, zl = zz).plot(ax = axes[1,2])
axes[1,2].set_title('du_dt_visc')

(mom.PFu+mom.du_dt_visc).isel(Time = tt, zl = zz).plot(ax = axes[1,3])
axes[1,3].set_title('PFu+ du_dt_visc')


mom.dudt.isel(Time = tt, zl = zz).plot(ax = axes[2,0])
axes[2,0].set_title('dudt')

RHS = mom.CAu.isel(Time = tt, zl = zz) + mom.PFu.isel(Time = tt, zl = zz) +\
      mom.u_accel_bt.isel(Time = tt) + mom.diffu.isel(Time = tt, zl = zz) + \
      mom.du_dt_visc.isel(Time = tt, zl = zz)
RHS.plot(ax = axes[2,1])
axes[2,1].set_title('RHS')

(RHS-mom.dudt.isel(Time = tt, zl = zz)).plot(ax = axes[2,2])
axes[2,2].set_title('Residual due to remapping')

axes[2,3].axis('off')


fig.subplots_adjust(wspace = 0.4, hspace = 0.4)
fig.suptitle('Time = 1 hour, Bottom Layer')
# Out:
# Text(0.5, 0.98, 'Time = 1 hour, Bottom Layer')

# %%
tt = -1
zz = -1
fig,axes = plt.subplots(nrows = 3, ncols = 4, figsize = (20,12))
prog.salt.isel(Time = tt, zl = zz).plot(ax = axes[0,0])
axes[0,0].set_title('salt')

prog.h.isel(Time = tt, zl = zz).plot(ax = axes[0,1])
axes[0,1].set_title('layer thickness')

mom.CAu.isel(Time = tt, zl = zz).plot(ax = axes[0,2])
axes[0,2].set_title('CAu')

mom.PFu.isel(Time = tt, zl = zz).plot(ax = axes[0,3])
axes[0,3].set_title('PFu')

mom.u_accel_bt.isel(Time = tt).plot(ax = axes[1,0])## no z dependence
axes[1,0].set_title('u_accel_bt')

mom.diffu.isel(Time = tt, zl = zz).plot(ax = axes[1,1]) 
axes[1,1].set_title('diffu')

mom.du_dt_visc.isel(Time = tt, zl = zz).plot(ax = axes[1,2])
axes[1,2].set_title('du_dt_visc')

(mom.PFu+mom.du_dt_visc).isel(Time = tt, zl = zz).plot(ax = axes[1,3])
axes[1,3].set_title('PFu+ du_dt_visc')

mom.dudt.isel(Time = tt, zl = zz).plot(ax = axes[2,0])
axes[2,0].set_title('dudt')

RHS = mom.CAu.isel(Time = tt, zl = zz) + mom.PFu.isel(Time = tt, zl = zz) +\
      mom.u_accel_bt.isel(Time = tt) + mom.diffu.isel(Time = tt, zl = zz) + \
      mom.du_dt_visc.isel(Time = tt, zl = zz)
RHS.plot(ax = axes[2,1])
axes[2,1].set_title('RHS')

(RHS-mom.dudt.isel(Time = tt, zl = zz)).plot(ax = axes[2,2])
axes[2,2].set_title('Residual due to remapping')

#axes[1,3].axis('off')
axes[2,3].axis('off')


fig.subplots_adjust(wspace = 0.4, hspace = 0.4)
fig.suptitle('Time = 5 days, Bottom Layer')
# Out:
# Text(0.5, 0.98, 'Time = 5 days, Bottom Layer')

# %%
tt = 0
zz = 0
fig,axes = plt.subplots(nrows = 3, ncols = 4, figsize = (20,12))
prog.salt.isel(Time = tt, zl = zz).plot(ax = axes[0,0])
axes[0,0].set_title('salt')

prog.h.isel(Time = tt, zl = zz).plot(ax = axes[0,1])
axes[0,1].set_title('layer thickness')

mom.CAu.isel(Time = tt, zl = zz).plot(ax = axes[0,2])
axes[0,2].set_title('CAu')

mom.PFu.isel(Time = tt, zl = zz).plot(ax = axes[0,3])
axes[0,3].set_title('PFu')

mom.u_accel_bt.isel(Time = tt).plot(ax = axes[1,0])## no z dependence
axes[1,0].set_title('u_accel_bt')

mom.diffu.isel(Time = tt, zl = zz).plot(ax = axes[1,1]) 
axes[1,1].set_title('diffu')

mom.du_dt_visc.isel(Time = tt, zl = zz).plot(ax = axes[1,2])
axes[1,2].set_title('du_dt_visc')

(mom.PFu+mom.du_dt_visc).isel(Time = tt, zl = zz).plot(ax = axes[1,3])
axes[1,3].set_title('PFu+ du_dt_visc')

mom.dudt.isel(Time = tt, zl = zz).plot(ax = axes[2,0])
axes[2,0].set_title('dudt')

RHS = mom.CAu.isel(Time = tt, zl = zz) + mom.PFu.isel(Time = tt, zl = zz) +\
      mom.u_accel_bt.isel(Time = tt) + mom.diffu.isel(Time = tt, zl = zz) + \
      mom.du_dt_visc.isel(Time = tt, zl = zz)
RHS.plot(ax = axes[2,1])
axes[2,1].set_title('RHS')

(RHS-mom.dudt.isel(Time = tt, zl = zz)).plot(ax = axes[2,2])
axes[2,2].set_title('Residual due to remapping')

#axes[1,3].axis('off')
axes[2,3].axis('off')


fig.subplots_adjust(wspace = 0.4, hspace = 0.4)
fig.suptitle('Time = 1 hour, Top Layer')
# Out:
# Text(0.5, 0.98, 'Time = 1 hour, Top Layer')

# %%
tt = -1
zz = 0
fig,axes = plt.subplots(nrows = 3, ncols = 4, figsize = (20,12))
prog.salt.isel(Time = tt, zl = zz).plot(ax = axes[0,0])
axes[0,0].set_title('salt')

prog.h.isel(Time = tt, zl = zz).plot(ax = axes[0,1])
axes[0,1].set_title('layer thickness')

mom.CAu.isel(Time = tt, zl = zz).plot(ax = axes[0,2])
axes[0,2].set_title('CAu')

mom.PFu.isel(Time = tt, zl = zz).plot(ax = axes[0,3])
axes[0,3].set_title('PFu')

mom.u_accel_bt.isel(Time = tt).plot(ax = axes[1,0])## no z dependence
axes[1,0].set_title('u_accel_bt')

mom.diffu.isel(Time = tt, zl = zz).plot(ax = axes[1,1]) 
axes[1,1].set_title('diffu')

mom.du_dt_visc.isel(Time = tt, zl = zz).plot(ax = axes[1,2])
axes[1,2].set_title('du_dt_visc')

(mom.PFu+mom.du_dt_visc).isel(Time = tt, zl = zz).plot(ax = axes[1,3])
axes[1,3].set_title('PFu+ du_dt_visc')

mom.dudt.isel(Time = tt, zl = zz).plot(ax = axes[2,0])
axes[2,0].set_title('dudt')

RHS = mom.CAu.isel(Time = tt, zl = zz) + mom.PFu.isel(Time = tt, zl = zz) +\
      mom.u_accel_bt.isel(Time = tt) + mom.diffu.isel(Time = tt, zl = zz) + \
      mom.du_dt_visc.isel(Time = tt, zl = zz)
RHS.plot(ax = axes[2,1])
axes[2,1].set_title('RHS')

(RHS-mom.dudt.isel(Time = tt, zl = zz)).plot(ax = axes[2,2])
axes[2,2].set_title('Residual due to remapping')

#axes[1,3].axis('off')
axes[2,3].axis('off')


fig.subplots_adjust(wspace = 0.4, hspace = 0.4)
fig.suptitle('Time = 5 days, Top Layer')
# Out:
# Text(0.5, 0.98, 'Time = 5 days, Top Layer')

# %% [markdown]
# Let's find the location with biggest velocities after 5 days and track each of these over time.

# %%
print(np.abs(prog.u.isel(Time = -1)).argmax(['zl','yh','xq']))

print('umax = '+str(np.abs(prog.u.isel(Time = -1)).max(['zl','yh','xq']).values))
# Out:
# {'zl': <xarray.DataArray 'u' ()>
# array(19)
# Coordinates:
#     Time     object 0001-01-06 00:00:00, 'yh': <xarray.DataArray 'u' ()>
# array(6)
# Coordinates:
#     Time     object 0001-01-06 00:00:00, 'xq': <xarray.DataArray 'u' ()>
# array(160)
# Coordinates:
#     Time     object 0001-01-06 00:00:00}
# umax = 0.010260346210635969

# %%
#tt = -1
zz = 19
yy = 6
xx = 160

fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
ax.plot(times, mom.CAu.isel(zl = zz, yh = yy, xq = xx), label = 'CAu')
ax.plot(times, mom.PFu.isel(zl = zz, yh = yy, xq = xx), label = 'PFu')
ax.plot(times, mom.u_accel_bt.isel(yh = yy, xq = xx), label = 'u_accel_bt')
ax.plot(times, mom.diffu.isel(zl = zz,yh = yy, xq = xx), label = 'diffu')
ax.plot(times, mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx), label = 'du_dt_visc')
ax.plot(times, mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'dudt')
RHS = mom.CAu.isel(zl = zz, yh = yy, xq = xx) + mom.PFu.isel(zl = zz, yh = yy, xq = xx) + \
    mom.u_accel_bt.isel(yh = yy, xq = xx) + mom.diffu.isel(zl = zz,yh = yy, xq = xx) + \
    mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx)
ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()

# %%
fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
ax.plot(times, mom.CAu.isel(zl = zz, yh = yy, xq = xx), label = 'CAu')
#ax.plot(times, mom.PFu.isel(zl = zz, yh = yy, xq = xx), label = 'PFu')
ax.plot(times, mom.u_accel_bt.isel(yh = yy, xq = xx), label = 'u_accel_bt')
#ax.plot(times, mom.diffu.isel(zl = zz,yh = yy, xq = xx), label = 'diffu')
#ax.plot(times, mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx), label = 'du_dt_visc')
ax.plot(times, mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'dudt')
RHS = mom.CAu.isel(zl = zz, yh = yy, xq = xx) + mom.PFu.isel(zl = zz, yh = yy, xq = xx) + \
    mom.u_accel_bt.isel(yh = yy, xq = xx) + mom.diffu.isel(zl = zz,yh = yy, xq = xx) + \
    mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx)
ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()

# %%
fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
#ax.plot(times, mom.CAu.isel(zl = zz, yh = yy, xq = xx), label = 'CAu')
#ax.plot(times, mom.PFu.isel(zl = zz, yh = yy, xq = xx), label = 'PFu')
#ax.plot(times, mom.u_accel_bt.isel(yh = yy, xq = xx), label = 'u_accel_bt')
#ax.plot(times, mom.diffu.isel(zl = zz,yh = yy, xq = xx), label = 'diffu')
#ax.plot(times, mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx), label = 'du_dt_visc')
#ax.plot(times, mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'dudt')
RHS = mom.CAu.isel(zl = zz, yh = yy, xq = xx) + mom.PFu.isel(zl = zz, yh = yy, xq = xx) + \
    mom.u_accel_bt.isel(yh = yy, xq = xx) + mom.diffu.isel(zl = zz,yh = yy, xq = xx) + \
    mom.du_dt_visc.isel(zl = zz,yh = yy, xq = xx)
#ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dudt.isel(zl = zz,yh = yy, xq = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()

# %%
print(np.abs(prog.v.isel(Time = -1)).argmax(['zl','yq','xh']))

print('vmax = '+str(np.abs(prog.v.isel(Time = -1)).max(['zl','yq','xh']).values))
# Out:
# {'zl': <xarray.DataArray 'v' ()>
# array(17)
# Coordinates:
#     Time     object 0001-01-06 00:00:00, 'yq': <xarray.DataArray 'v' ()>
# array(36)
# Coordinates:
#     Time     object 0001-01-06 00:00:00, 'xh': <xarray.DataArray 'v' ()>
# array(160)
# Coordinates:
#     Time     object 0001-01-06 00:00:00}
# vmax = 0.005415689799864496

# %%
#tt = -1
zz = 17
yy = 36
xx = 160

fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
ax.plot(times, mom.CAv.isel(zl = zz, yq = yy, xh = xx), label = 'CAv')
ax.plot(times, mom.PFv.isel(zl = zz, yq = yy, xh = xx), label = 'PFv')
ax.plot(times, mom.v_accel_bt.isel(yq = yy, xh = xx), label = 'v_accel_bt')
ax.plot(times, mom.diffv.isel(zl = zz,yq = yy, xh = xx), label = 'diffv')
ax.plot(times, mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx), label = 'dv_dt_visc')
ax.plot(times, mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'dvdt')
RHS = mom.CAv.isel(zl = zz, yq = yy, xh = xx) + mom.PFv.isel(zl = zz, yq = yy, xh = xx) + \
    mom.v_accel_bt.isel(yq = yy, xh = xx) + mom.diffv.isel(zl = zz,yq = yy, xh = xx) + \
    mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx)
ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()
plt.show()

fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
ax.plot(times, mom.CAv.isel(zl = zz, yq = yy, xh = xx), label = 'CAv')
#ax.plot(times, mom.PFv.isel(zl = zz, yq = yy, xh = xx), label = 'PFv')
ax.plot(times, mom.v_accel_bt.isel(yq = yy, xh = xx), label = 'v_accel_bt')
#ax.plot(times, mom.diffv.isel(zl = zz,yq = yy, xh = xx), label = 'diffv')
#ax.plot(times, mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx), label = 'dv_dt_visc')
ax.plot(times, mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'dvdt')
RHS = mom.CAv.isel(zl = zz, yq = yy, xh = xx) + mom.PFv.isel(zl = zz, yq = yy, xh = xx) + \
    mom.v_accel_bt.isel(yq = yy, xh = xx) + mom.diffv.isel(zl = zz,yq = yy, xh = xx) + \
    mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx)
ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()
plt.show()

fig,ax = plt.subplots(figsize = (10,4))
times = np.arange(1,len(mom.Time)+1)/24
#ax.plot(times, mom.CAv.isel(zl = zz, yq = yy, xh = xx), label = 'CAv')
#ax.plot(times, mom.PFv.isel(zl = zz, yq = yy, xh = xx), label = 'PFv')
#ax.plot(times, mom.v_accel_bt.isel(yq = yy, xh = xx), label = 'v_accel_bt')
#ax.plot(times, mom.diffv.isel(zl = zz,yq = yy, xh = xx), label = 'diffv')
#ax.plot(times, mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx), label = 'dv_dt_visc')
#ax.plot(times, mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'dvdt')
RHS = mom.CAv.isel(zl = zz, yq = yy, xh = xx) + mom.PFv.isel(zl = zz, yq = yy, xh = xx) + \
    mom.v_accel_bt.isel(yq = yy, xh = xx) + mom.diffv.isel(zl = zz,yq = yy, xh = xx) + \
    mom.dv_dt_visc.isel(zl = zz,yq = yy, xh = xx)
#ax.plot(times, RHS, label = 'RHS', linestyle = '--')
ax.plot(times, RHS - mom.dvdt.isel(zl = zz,yq = yy, xh = xx), label = 'Residual due to remapping')

ax.set_xlabel('Time (days)')
ax.set_ylabel('Budget contribution (m/s^2)')
plt.legend()
plt.show()

# %% [markdown]
# See if large velocities correlate with having PFu and du_dt_visc not cancelling out

# %%
prog.u.isel(zl = 0,Time = 0).plot()

# %%
(mom.PFu+mom.du_dt_visc).isel(zl = 0,Time = 0).plot()
plt.show()
(mom.diffu).isel(zl = 0,Time = 0).plot()
plt.show()
(mom.u_accel_bt).isel(Time = 0).plot()
