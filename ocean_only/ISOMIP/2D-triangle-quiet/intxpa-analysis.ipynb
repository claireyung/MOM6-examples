# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import netCDF4 as nc
import cmocean as cm

from xgcm import Grid

# %%
base = 'intxpa-testing/'
files = ['z-og','z-mwipg','z-intxpa','z-mwipg-intxpa',#'sigma-og'
         'sigma-intxpa',]

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False)
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %% [markdown]
# Sigma initialization still broken.... need to use hackmode.

# %%
base = 'intxpa-testing/'
files = ['z-og-vertfront','z-og-vertfront-mwipg','z-og-vertfront-intxpa','z-og-vertfront-mwipg-intxpa']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False)
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %%
base = 'intxpa-testing/'
files = ['z-og-grounding','z-og-grounding-mwipg','z-og-grounding-intxpa','z-og-grounding-mwipg-intxpa']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False)
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %%
base = 'intxpa-testing/'
files = ['z-og-grounding','z-og-grounding-mwipg','z-og-grounding-intxpa','z-og-grounding-mwipg-intxpa']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False, vmax = 1e-5,vmin=-1e-5,cmap = 'RdBu_r')
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False, vmax = 1e-5,vmin=-1e-5,cmap = 'RdBu_r')
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %%
base = 'intxpa-testing/'
files = ['z-og-grounding','z-og-grounding-mwipg','z-og-grounding-intxpa','z-og-grounding-mwipg-intxpa']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False, vmax = 1e-7,vmin=-1e-7,cmap = 'RdBu_r')
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False, vmax = 1e-7,vmin=-1e-7,cmap = 'RdBu_r')
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %% [markdown]
# # zoom in on grounding point

# %%
base = 'intxpa-testing/'
files = ['z-og-grounding','z-og-grounding-mwipg','z-og-grounding-intxpa','z-og-grounding-mwipg-intxpa']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False, vmax = 1e-5,vmin=-1e-5,cmap = 'RdBu_r')
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False, vmax = 1e-5,vmin=-1e-5,cmap = 'RdBu_r')
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))
    axes[0].set_xlim(319,400)
    axes[1].set_xlim(319,400)

# %% [markdown]
# # check timestep 1

# %%
prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-t1.nc')
prog.u.isel(yh = 0, Time = 0).plot( yincrease = False)

# Not close enough to zero.

# %%
prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-t1-bottom.nc')
prog.u.isel(yh = 0, Time = 0).plot( yincrease = False)
plt.show()
prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-t1-bottom-mwipg.nc')
prog.u.isel(yh = 0, Time = 0).plot( yincrease = False)
plt.show()
# prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-t1-precise-psurf.nc')
# prog.u.isel(yh = 0, Time = 0).plot( yincrease = False)
# plt.show()
# prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-t1-precise-psurf.nc')
# prog.u.isel(yh = 0, Time = 0).plot( yincrease = False, vmax = 1e-9, vmin = -1e-9)
# plt.show()

# %% [markdown]
# # the initialization pressure matters
#
# reduce to 1e-13

# %%
base = 'intxpa-testing/'
files = ['z-intxpa-precise-psurf','z-intxpa-precise-psurf-grounding','z-intxpa-precise-psurf-vertfront']

time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r')
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r')
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))
    
    
for i in np.arange(1,2):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r', vmin = -1e-8,vmax = 1e-8)
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r', vmin = -1e-6,vmax = 1e-6)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %%
prog = xr.open_dataset('intxpa-testing/prog-z-intxpa-precise-psurf-grounding.nc')
prog.h.isel(xh = 0,Time = 0,yh = 0).values
# Out:
# array([1.03560776e-12, 1.03560776e-12, 1.03560776e-12, 1.03560776e-12,
#        1.03560776e-12, 1.03560776e-12, 1.03560776e-12, 1.03560776e-12,
#        1.03560776e-12, 1.03560776e-12, 9.59610624e-09, 1.00000000e-12,
#        1.01437211e-12, 1.00000000e-12, 1.03560776e-12, 1.01437211e-12,
#        1.00000000e-12, 1.01437211e-12, 1.00000000e-12, 1.03560776e-12,
#        1.01437211e-12, 1.00000000e-12, 1.01437211e-12, 1.00000000e-12,
#        1.03560776e-12])

# %% [markdown]
# # to prove (or not prove) a point: same config with melt on

# %%
base = 'intxpa-testing/'
files = ['z-intxpa-precise-psurf-vertfront','z-intxpa-precise-psurf-vertfront-melton',
         'z-intxpa-precise-psurf-vertfront-melton-us01','layer-intxpa-precise-psurf-vertfront-melton-us01',
        'layer-intxpa-precise-psurf-vertfront']
time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r')
    prog.u.isel(yh = 0, Time = time).plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r')
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t = '+str(time))

# %%
base = 'intxpa-testing/'
files = ['z-intxpa-precise-psurf-vertfront','z-intxpa-precise-psurf-vertfront-melton-us01']
time = -1

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r', vmax = 5e-4, vmin = -5e-4)
    prog.u.isel(yh = 0).mean('Time').plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r', vmax = 5e-4, vmin = -5e-4)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,,mean t')

# %%
base = 'intxpa-testing/'
files = ['layer-intxpa-precise-psurf-vertfront-melton-us01',
        'layer-intxpa-precise-psurf-vertfront']

for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 2, figsize = (12,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r', vmax = 5e-3, vmin = -5e-3)
    prog.u.isel(yh = 0).mean('Time').plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r', vmax = 5e-3, vmin = -5e-3)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t mean')

# %%
base = 'intxpa-testing/'
files = ['sigma-intxpa','sigma-og','sigma-intxpa-grounding','sigma-og-grounding']
time = -1
for i in np.arange(len(files)):
    prog = xr.open_dataset(base+'prog-'+files[i]+'.nc')
    fig, axes = plt.subplots(ncols = 3, figsize = (20,4))
    prog.u.isel(yh = 0, Time = 0).plot(ax = axes[0], yincrease = False,cmap = 'RdBu_r')#, vmax=1e-5,vmin=-1e-5)
    prog.u.isel(yh = 0).isel(Time = time).plot(ax = axes[1], yincrease = False,cmap = 'RdBu_r')#, vmax=1e-5,vmin=-1e-5)
    prog.h.isel(yh = 0).isel(Time = 0).plot(ax = axes[2], yincrease = False)#, vmax=1e-5,vmin=-1e-5)
    axes[0].set_title(files[i]+', u,t = 1hr')
    axes[1].set_title(files[i]+', u,t='+str(time))
    axes[2].set_title(files[i]+', h')
